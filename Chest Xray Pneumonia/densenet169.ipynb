# %% [markdown]
# <h2>Changes:</h2>
# <ol>
#     <li>DenseNet 169</li>
# </ol>

# %%
import torch
import torch.nn as nn
import torch.optim
import torchvision
from torchvision import datasets, transforms
import torchvision.models as models
from torchvision.models import densenet169, DenseNet169_Weights
from torch.utils.data import DataLoader, random_split, Subset, WeightedRandomSampler

from sklearn.model_selection import StratifiedKFold

from torchmetrics.classification import Accuracy

# %%
device= torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
train_transform= transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

val_transform= transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

test_transform= transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
full_train_dir= "/kaggle/input/chest-xray-pneumonia/chest_xray/train"
full_train= datasets.ImageFolder(root=full_train_dir, transform= train_transform)
full_train_val= datasets.ImageFolder(root=full_train_dir, transform= val_transform)

# full_train.samples returns (image, label) so s[1] imples fetching the labels
labels = [s[1] for s in full_train.samples]

test_dir= "/kaggle/input/chest-xray-pneumonia/chest_xray/test"
test_set= datasets.ImageFolder(root=test_dir, transform= test_transform)

# %%
# Treating class imbalance
class_counts= torch.tensor([labels.count(0), labels.count(1)], dtype= torch.float)
class_weights= 1./class_counts
sample_weights= class_weights[[label for _, label in full_train.samples]]


print(class_counts, class_weights, sample_weights)

# Dataset is imbalanced in 1:3 ratio
# Out:
# tensor([1341., 3875.]) tensor([0.0007, 0.0003]) tensor([0.0007, 0.0007, 0.0007,  ..., 0.0003, 0.0003, 0.0003])

# %%
model= models.resnet18(weights=ResNet18_Weights.DEFAULT)
model.fc= nn.Sequential(
    nn.Linear(model.fc.in_features, 512),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(512,2)
)
model=model.to(device)

# %%
def train(dataloader, model, loss_function, optimizer):
    model.train()
    total_loss=0

    for batch, (image, label) in enumerate(dataloader):
        image, label= image.to(device), label.to(device)
        prediction= model(image)
        loss= loss_function(prediction, label)
        loss.backward()

        #Gradient clipping to mitigate the exploding gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        optimizer.step()
        scheduler.step()
        optimizer.zero_grad()

        total_loss+= loss
    avg_loss= total_loss/len(dataloader)
    print(f"Training Average Loss: {avg_loss:.4f}")

# %%
val_accuracy= Accuracy(task="multiclass", num_classes=2).to(device)

def validate(dataloader, model, loss_function):
    model.eval()
    total_loss=0
    val_accuracy.reset()

    with torch.no_grad():
        for image, label in dataloader:
            image, label= image.to(device), label.to(device)
            prediction= model(image)
            loss= loss_function(prediction, label)
            total_loss+= loss

            val_accuracy.update(prediction, label)
            
        avg_loss= total_loss/ len(dataloader)
        accuracy= val_accuracy.compute()*100
        print(f"Validation Loss: {avg_loss:.4f}")
        print(f"Validation Accuracy: {accuracy:.2f}")

    return accuracy

# %%
test_accuracy= Accuracy(task="multiclass", num_classes=2).to(device)

def test(dataloader, model, loss_function):
    model.eval()
    total_loss=0
    val_accuracy.reset()

    with torch.no_grad():
        for image, label in dataloader:
            image= image.to(device)  # shape: (batch_size, C, H, W)
            label= label.to(device)  # shape: (batch_size,)
            prediction= model(image)
            loss= loss_function(prediction, label)
            total_loss+= loss

            test_accuracy.update(prediction, label)

        avg_loss= total_loss/ len(dataloader)
        accuracy= test_accuracy.compute()*100
    print(f"Test Loss: {avg_loss:.4f}")
    print(f"Test Accuracy: {accuracy:.2f}")

    return accuracy

# %%
epochs=20

skf= StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for fold, (train_idx, val_idx) in enumerate(skf.split(full_train.samples, labels)):
    print(f"\n--------------Fold {fold+1}------------")
    print(f"Train size: {len(train_idx)}, Val size: {len(val_idx)}")

    train_subset= Subset(full_train, train_idx)
    val_subset= Subset(full_train_val, val_idx)

    #Creating train sampler
    train_sampler= WeightedRandomSampler(
        weights=sample_weights[train_idx],
        num_samples=len(train_idx),
        replacement=True
    )

    
    train_loader= DataLoader(train_subset, sampler= train_sampler, batch_size=64, shuffle=False, num_workers=2) # shuffle has to be false!!
    val_loader= DataLoader(val_subset, batch_size=64, shuffle=False, num_workers=2)


    model = models.densenet169(weights=DenseNet169_Weights.DEFAULT) 
    model.classifier = nn.Sequential(
        nn.Linear(model.classifier.in_features, 512),
        nn.ReLU(),
        nn.Dropout(0.5),
        nn.Linear(512, 2)
    )
    model = model.to(device)
    
    loss_function= nn.CrossEntropyLoss()
    optimizer= torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
    scheduler= torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.005, steps_per_epoch= len(train_loader), epochs= epochs)

    best_val_acc= 0.0

    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs}")
        train(train_loader, model, loss_function, optimizer)
        val_acc= validate(val_loader, model, loss_function)

        if val_acc > best_val_acc:
            best_val_acc= val_acc
    print(f"Best Validation Accuracy in Fold {fold+1}: {best_val_acc:.2f}%")
    print(f"-----------------------------------------------------------------")


print("\n")
test_loader= DataLoader(test_set, batch_size=64, shuffle=False, num_workers=2)
test(test_loader, model, loss_function)
# Out:
# --------------Fold 1------------
# Train size: 4172, Val size: 1044
# Epoch 1/20
# Training Average Loss: 0.1284
# Validation Loss: 0.1018
# Validation Accuracy: 96.26
# Epoch 2/20
# Training Average Loss: 0.1072
# Validation Loss: 0.6081
# Validation Accuracy: 88.31
# Epoch 3/20
# Training Average Loss: 0.1255
# Validation Loss: 9.3175
# Validation Accuracy: 33.62
# Epoch 4/20
# Training Average Loss: 0.1633
# Validation Loss: 0.1911
# Validation Accuracy: 94.73
# Epoch 5/20
# Training Average Loss: 0.1559
# Validation Loss: 1.6980
# Validation Accuracy: 63.70
# Epoch 6/20
# Training Average Loss: 0.1176
# Validation Loss: 0.3994
# Validation Accuracy: 85.92
# Epoch 7/20
# Training Average Loss: 0.0967
# Validation Loss: 0.1079
# Validation Accuracy: 95.69
# Epoch 8/20
# Training Average Loss: 0.1170
# Validation Loss: 0.3843
# Validation Accuracy: 87.26
# Epoch 9/20
# Training Average Loss: 0.0969
# Validation Loss: 0.1140
# Validation Accuracy: 95.40
# Epoch 10/20
# Training Average Loss: 0.0790
# Validation Loss: 0.0577
# Validation Accuracy: 97.70
# Epoch 11/20
# Training Average Loss: 0.0940
# Validation Loss: 0.1090
# Validation Accuracy: 95.79
# Epoch 12/20
# Training Average Loss: 0.0572
# Validation Loss: 0.0749
# Validation Accuracy: 97.32
# Epoch 13/20
# Training Average Loss: 0.0661
# Validation Loss: 0.0734
# Validation Accuracy: 96.93
# Epoch 14/20
# Training Average Loss: 0.0616
# Validation Loss: 0.0524
# Validation Accuracy: 97.99
# Epoch 15/20
# Training Average Loss: 0.0497
# Validation Loss: 0.0576
# Validation Accuracy: 97.70
# Epoch 16/20
# Training Average Loss: 0.0458
# Validation Loss: 0.0565
# Validation Accuracy: 97.22
# Epoch 17/20
# Training Average Loss: 0.0326
# Validation Loss: 0.0598
# Validation Accuracy: 97.80
# Epoch 18/20
# Training Average Loss: 0.0245
# Validation Loss: 0.0750
# Validation Accuracy: 97.80
# Epoch 19/20
# Training Average Loss: 0.0215
# Validation Loss: 0.0666
# Validation Accuracy: 97.70
# Epoch 20/20
# Training Average Loss: 0.0234
# Validation Loss: 0.0662
# Validation Accuracy: 97.70
# Best Validation Accuracy in Fold 1: 97.99%
# -----------------------------------------------------------------
#
# --------------Fold 2------------
# Train size: 4173, Val size: 1043
# Epoch 1/20
# Training Average Loss: 0.1255
# Validation Loss: 0.0892
# Validation Accuracy: 97.12
# Epoch 2/20
# Training Average Loss: 0.1107
# Validation Loss: 0.3301
# Validation Accuracy: 88.88
# Epoch 3/20
# Training Average Loss: 0.1352
# Validation Loss: 0.6748
# Validation Accuracy: 89.36
# Epoch 4/20
# Training Average Loss: 0.1522
# Validation Loss: 0.8942
# Validation Accuracy: 85.14
# Epoch 5/20
# Training Average Loss: 0.1343
# Validation Loss: 0.2532
# Validation Accuracy: 91.66
# Epoch 6/20
# Training Average Loss: 0.1280
# Validation Loss: 0.1824
# Validation Accuracy: 92.62
# Epoch 7/20
# Training Average Loss: 0.1244
# Validation Loss: 0.1001
# Validation Accuracy: 96.84
# Epoch 8/20
# Training Average Loss: 0.0956
# Validation Loss: 0.1019
# Validation Accuracy: 96.16
# Epoch 9/20
# Training Average Loss: 0.0996
# Validation Loss: 0.0913
# Validation Accuracy: 96.55
# Epoch 10/20
# Training Average Loss: 0.0920
# Validation Loss: 0.0808
# Validation Accuracy: 96.93
# Epoch 11/20
# Training Average Loss: 0.0888
# Validation Loss: 0.0504
# Validation Accuracy: 98.08
# Epoch 12/20
# Training Average Loss: 0.0688
# Validation Loss: 0.0488
# Validation Accuracy: 98.18
# Epoch 13/20
# Training Average Loss: 0.0598
# Validation Loss: 0.0724
# Validation Accuracy: 97.41
# Epoch 14/20
# Training Average Loss: 0.0488
# Validation Loss: 0.0463
# Validation Accuracy: 97.70
# Epoch 15/20
# Training Average Loss: 0.0606
# Validation Loss: 0.0577
# Validation Accuracy: 97.99
# Epoch 16/20
# Training Average Loss: 0.0471
# Validation Loss: 0.0489
# Validation Accuracy: 97.70
# Epoch 17/20
# Training Average Loss: 0.0399
# Validation Loss: 0.0418
# Validation Accuracy: 98.37
# Epoch 18/20
# Training Average Loss: 0.0356
# Validation Loss: 0.0439
# Validation Accuracy: 98.37
# Epoch 19/20
# Training Average Loss: 0.0253
# Validation Loss: 0.0381
# Validation Accuracy: 98.75
# Epoch 20/20
# Training Average Loss: 0.0246
# Validation Loss: 0.0391
# Validation Accuracy: 98.56
# Best Validation Accuracy in Fold 2: 98.75%
# -----------------------------------------------------------------
#
# --------------Fold 3------------
# Train size: 4173, Val size: 1043
# Epoch 1/20
# Training Average Loss: 0.1325
# Validation Loss: 0.5321
# Validation Accuracy: 86.39
# Epoch 2/20
# Training Average Loss: 0.1151
# Validation Loss: 0.1760
# Validation Accuracy: 94.06
# Epoch 3/20
# Training Average Loss: 0.1330
# Validation Loss: 0.9459
# Validation Accuracy: 71.43
# Epoch 4/20
# Training Average Loss: 0.1285
# Validation Loss: 14.8421
# Validation Accuracy: 32.12
# Epoch 5/20
# Training Average Loss: 0.1448
# Validation Loss: 0.3647
# Validation Accuracy: 90.70
# Epoch 6/20
# Training Average Loss: 0.1416
# Validation Loss: 4.5165
# Validation Accuracy: 40.17
# Epoch 7/20
# Training Average Loss: 0.1156
# Validation Loss: 0.1876
# Validation Accuracy: 94.44
# Epoch 8/20
# Training Average Loss: 0.0952
# Validation Loss: 0.7197
# Validation Accuracy: 85.52
# Epoch 9/20
# Training Average Loss: 0.0877
# Validation Loss: 0.1022
# Validation Accuracy: 95.78
# Epoch 10/20
# Training Average Loss: 0.0897
# Validation Loss: 0.1093
# Validation Accuracy: 95.59
# Epoch 11/20
# Training Average Loss: 0.0860
# Validation Loss: 0.0863
# Validation Accuracy: 96.36
# Epoch 12/20
# Training Average Loss: 0.0647
# Validation Loss: 0.0982
# Validation Accuracy: 96.16
# Epoch 13/20
# Training Average Loss: 0.0623
# Validation Loss: 0.0688
# Validation Accuracy: 97.41
# Epoch 14/20
# Training Average Loss: 0.0501
# Validation Loss: 0.0648
# Validation Accuracy: 97.89
# Epoch 15/20
# Training Average Loss: 0.0502
# Validation Loss: 0.0550
# Validation Accuracy: 97.51
# Epoch 16/20
# Training Average Loss: 0.0332
# Validation Loss: 0.0998
# Validation Accuracy: 96.64
# Epoch 17/20
# Training Average Loss: 0.0309
# Validation Loss: 0.0567
# Validation Accuracy: 98.27
# Epoch 18/20
# Training Average Loss: 0.0317
# Validation Loss: 0.0589
# Validation Accuracy: 98.18
# Epoch 19/20
# Training Average Loss: 0.0259
# Validation Loss: 0.0559
# Validation Accuracy: 98.27
# Epoch 20/20
# Training Average Loss: 0.0251
# Validation Loss: 0.0580
# Validation Accuracy: 98.27
# Best Validation Accuracy in Fold 3: 98.27%
# -----------------------------------------------------------------
#
# --------------Fold 4------------
# Train size: 4173, Val size: 1043
# Epoch 1/20
# Training Average Loss: 0.1338
# Validation Loss: 0.0513
# Validation Accuracy: 98.08
# Epoch 2/20
# Training Average Loss: 0.0940
# Validation Loss: 1.4230
# Validation Accuracy: 69.32
# Epoch 3/20
# Training Average Loss: 0.1269
# Validation Loss: 0.2683
# Validation Accuracy: 91.47
# Epoch 4/20
# Training Average Loss: 0.1473
# Validation Loss: 4.2602
# Validation Accuracy: 53.31
# Epoch 5/20
# Training Average Loss: 0.1808
# Validation Loss: 0.3073
# Validation Accuracy: 91.95
# Epoch 6/20
# Validation Loss: 0.0537
# Validation Accuracy: 98.08
# Epoch 15/20
# Training Average Loss: 0.0446
# Validation Loss: 0.0477
# Validation Accuracy: 97.99
# Epoch 16/20
# Training Average Loss: 0.0463
# Validation Loss: 0.0448
# Validation Accuracy: 98.27
# Epoch 17/20
# Training Average Loss: 0.0390
# Validation Loss: 0.0446
# Validation Accuracy: 98.18
# Epoch 18/20
# Training Average Loss: 0.0305
# Validation Loss: 0.0310
# Validation Accuracy: 98.66
# Epoch 19/20
# Training Average Loss: 0.0346
# Validation Loss: 0.0416
# Validation Accuracy: 98.56
# Epoch 20/20
# Training Average Loss: 0.0266
# Validation Loss: 0.0346
# Validation Accuracy: 98.37
# Best Validation Accuracy in Fold 4: 98.66%
# -----------------------------------------------------------------
#
# --------------Fold 5------------
# Train size: 4173, Val size: 1043
# Epoch 1/20
# Training Average Loss: 0.1371
# Validation Loss: 0.2618
# Validation Accuracy: 90.32
# Epoch 2/20
# Training Average Loss: 0.1234
# Validation Loss: 0.3200
# Validation Accuracy: 92.43
# Epoch 3/20
# Training Average Loss: 0.1240
# Validation Loss: 5.8483
# Validation Accuracy: 32.89
# Epoch 4/20
# Training Average Loss: 0.1364
# Validation Loss: 0.3052
# Validation Accuracy: 93.38
# Epoch 5/20
# Training Average Loss: 0.1536
# Validation Loss: 0.3035
# Validation Accuracy: 89.26
# Epoch 6/20
# Training Average Loss: 0.1503
# Validation Loss: 0.4113
# Validation Accuracy: 84.28
# Epoch 7/20
# Training Average Loss: 0.1149
# Validation Loss: 0.1333
# Validation Accuracy: 94.44
# Epoch 8/20
# Training Average Loss: 0.1122
# Validation Loss: 1.4860
# Validation Accuracy: 77.95
# Epoch 9/20
# Training Average Loss: 0.0776
# Validation Loss: 0.1104
# Validation Accuracy: 95.78
# Epoch 10/20
# Training Average Loss: 0.0924
# Validation Loss: 0.1521
# Validation Accuracy: 96.16
# Epoch 11/20
# Training Average Loss: 0.0875
# Validation Loss: 0.1856
# Validation Accuracy: 92.14
# Epoch 12/20
# Training Average Loss: 0.0656
# Validation Loss: 0.0708
# Validation Accuracy: 96.93
# Epoch 13/20
# Training Average Loss: 0.0544
# Validation Loss: 0.0589
# Validation Accuracy: 97.99
# Epoch 14/20
# Training Average Loss: 0.0493
# Validation Loss: 0.0613
# Validation Accuracy: 97.60
# Epoch 15/20
# Training Average Loss: 0.0466
# Validation Loss: 0.0475
# Validation Accuracy: 98.37
# Epoch 16/20
# Training Average Loss: 0.0349
# Validation Loss: 0.0531
# Validation Accuracy: 98.47
# Epoch 17/20
# Training Average Loss: 0.0258
# Validation Loss: 0.0755
# Validation Accuracy: 96.93
# Epoch 18/20
# Training Average Loss: 0.0277
# Validation Loss: 0.0440
# Validation Accuracy: 98.37
# Epoch 19/20
# Training Average Loss: 0.0299
# Validation Loss: 0.0382
# Validation Accuracy: 98.56
# Epoch 20/20
# Training Average Loss: 0.0272
# Validation Loss: 0.0381
# Validation Accuracy: 98.47
# Best Validation Accuracy in Fold 5: 98.56%
# -----------------------------------------------------------------
#
#
# Test Loss: 0.9686
# Test Accuracy: 82.85
# tensor(82.8526, device='cuda:0')
