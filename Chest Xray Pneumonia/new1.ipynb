# %%
import torch
import torch.nn as nn
import torch.optim
import torchvision
from torchvision import datasets, transforms
import torchvision.models as models
from torchvision.models import resnet18, ResNet18_Weights
from torch.utils.data import DataLoader, random_split, Subset, WeightedRandomSampler

from sklearn.model_selection import StratifiedKFold

from torchmetrics.classification import Accuracy

# %%
device= torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
train_transform= transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

val_transform= transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

test_transform= transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
full_train_dir= "/kaggle/input/chest-xray-pneumonia/chest_xray/train"
full_train= datasets.ImageFolder(root=full_train_dir, transform= train_transform)
full_train_val= datasets.ImageFolder(root=full_train_dir, transform= val_transform)

# full_train.samples returns (image, label) so s[1] imples fetching the labels
labels = [s[1] for s in full_train.samples]

test_dir= "/kaggle/input/chest-xray-pneumonia/chest_xray/test"
test_set= datasets.ImageFolder(root=test_dir, transform= test_transform)

# %%
# Treating class imbalance
class_counts= torch.tensor([labels.count(0), labels.count(1)], dtype= torch.float)
class_weights= 1./class_counts
sample_weights= class_weights[[label for _, label in full_train.samples]]


print(class_counts, class_weights, sample_weights)

# Dataset is imbalanced in 1:3 ratio
# Out:
# tensor([1341., 3875.]) tensor([0.0007, 0.0003]) tensor([0.0007, 0.0007, 0.0007,  ..., 0.0003, 0.0003, 0.0003])

# %%
model= models.resnet18(weights=ResNet18_Weights.DEFAULT)
model.fc= nn.Sequential(
    nn.Linear(model.fc.in_features, 512),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(512,2)
)
model=model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 158MB/s]

# %%
def train(dataloader, model, loss_function, optimizer):
    model.train()
    total_loss=0

    for batch, (image, label) in enumerate(dataloader):
        image, label= image.to(device), label.to(device)
        prediction= model(image)
        loss= loss_function(prediction, label)
        loss.backward()
        optimizer.step()
        scheduler.step()
        optimizer.zero_grad()

        total_loss+= loss
    avg_loss= total_loss/len(dataloader)
    print(f"Training Average Loss: {avg_loss:.4f}")

# %%
val_accuracy= Accuracy(task="multiclass", num_classes=2).to(device)

def validate(dataloader, model, loss_function):
    model.eval()
    total_loss=0
    val_accuracy.reset()

    with torch.no_grad():
        for image, label in dataloader:
            image, label= image.to(device), label.to(device)
            prediction= model(image)
            loss= loss_function(prediction, label)
            total_loss+= loss

            val_accuracy.update(prediction, label)
            
        avg_loss= total_loss/ len(dataloader)
        accuracy= val_accuracy.compute()*100
        print(f"Validation Loss: {avg_loss:.4f}")
        print(f"Validation Accuracy: {accuracy:.2f}")

    return accuracy

# %%
test_accuracy= Accuracy(task="multiclass", num_classes=2).to(device)

def test(dataloader, model, loss_function):
    model.eval()
    total_loss=0
    val_accuracy.reset()

    with torch.no_grad():
        for image, label in dataloader:
            image= image.to(device)  # shape: (batch_size, C, H, W)
            label= label.to(device)  # shape: (batch_size,)
            prediction= model(image)
            loss= loss_function(prediction, label)
            total_loss+= loss

            test_accuracy.update(prediction, label)

        avg_loss= total_loss/ len(dataloader)
        accuracy= test_accuracy.compute()*100
    print(f"Test Loss: {avg_loss:.4f}")
    print(f"Test Accuracy: {accuracy:.2f}")

    return accuracy

# %%
epochs=15

skf= StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for fold, (train_idx, val_idx) in enumerate(skf.split(full_train.samples, labels)):
    print(f"\n--------------Fold {fold+1}------------")
    print(f"Train size: {len(train_idx)}, Val size: {len(val_idx)}")

    train_subset= Subset(full_train, train_idx)
    val_subset= Subset(full_train_val, val_idx)

    #Creating train sampler
    train_sampler= WeightedRandomSampler(
        weights=sample_weights[train_idx],
        num_samples=len(train_idx),
        replacement=True
    )

    
    train_loader= DataLoader(train_subset, sampler= train_sampler, batch_size=64, shuffle=False, num_workers=2) # shuffle has to be false!!
    val_loader= DataLoader(val_subset, batch_size=64, shuffle=False, num_workers=2)


    model= models.resnet18(weights=ResNet18_Weights.DEFAULT)
    model.fc= nn.Sequential(
        nn.Linear(model.fc.in_features, 512),
        nn.ReLU(),
        nn.Dropout(0.4),
        nn.Linear(512,2)
    )
    model=model.to(device)
    
    loss_function= nn.CrossEntropyLoss()
    optimizer= torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
    scheduler= torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.01, steps_per_epoch= len(train_loader), epochs= epochs)

    best_val_acc= 0.0

    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs}")
        train(train_loader, model, loss_function, optimizer)
        val_acc= validate(val_loader, model, loss_function)

        if val_acc > best_val_acc:
            best_val_acc= val_acc
    print(f"Best Validation Accuracy in Fold {fold+1}: {best_val_acc:.2f}%")
    print(f"-----------------------------------------------------------------")


print("\n")
test_loader= DataLoader(test_set, batch_size=64, shuffle=False, num_workers=2)
test(test_loader, model, loss_function)
# Out:
# --------------Fold 1------------
# Train size: 4172, Val size: 1044
# Epoch 1/15
# Training Average Loss: 0.1337
# Validation Loss: 0.8128
# Validation Accuracy: 83.72
# Epoch 2/15
# Training Average Loss: 0.1286
# Validation Loss: 6.0222
# Validation Accuracy: 45.59
# Epoch 3/15
# Training Average Loss: 0.2717
# Validation Loss: 157.4154
# Validation Accuracy: 26.15
# Epoch 4/15
# Training Average Loss: 0.2740
# Validation Loss: 0.9770
# Validation Accuracy: 65.52
# Epoch 5/15
# Training Average Loss: 0.1966
# Validation Loss: 0.3845
# Validation Accuracy: 85.82
# Epoch 6/15
# Training Average Loss: 0.1880
# Validation Loss: 0.3475
# Validation Accuracy: 83.33
# Epoch 7/15
# Training Average Loss: 0.1911
# Validation Loss: 0.6451
# Validation Accuracy: 75.67
# Epoch 8/15
# Training Average Loss: 0.1849
# Validation Loss: 0.1349
# Validation Accuracy: 94.35
# Epoch 9/15
# Training Average Loss: 0.1522
# Validation Loss: 0.1209
# Validation Accuracy: 96.07
# Epoch 10/15
# Training Average Loss: 0.1431
# Validation Loss: 1.0282
# Validation Accuracy: 59.39
# Epoch 11/15
# Training Average Loss: 0.1160
# Validation Loss: 0.3668
# Validation Accuracy: 85.34
# Epoch 12/15
# Training Average Loss: 0.1033
# Validation Loss: 0.1104
# Validation Accuracy: 95.69
# Epoch 13/15
# Training Average Loss: 0.0836
# Validation Loss: 0.0712
# Validation Accuracy: 96.93
# Epoch 14/15
# Training Average Loss: 0.0800
# Validation Loss: 0.0737
# Validation Accuracy: 97.22
# Epoch 15/15
# Training Average Loss: 0.0736
# Validation Loss: 0.0700
# Validation Accuracy: 97.22
# Best Validation Accuracy in Fold 1: 97.22%
# -----------------------------------------------------------------
#
# --------------Fold 2------------
# Train size: 4173, Val size: 1043
# Epoch 1/15
# Training Average Loss: 0.1241
# Validation Loss: 0.1257
# Validation Accuracy: 96.74
# Epoch 2/15
# Training Average Loss: 0.1407
# Validation Loss: 2.0981
# Validation Accuracy: 73.83
# Epoch 3/15
# Training Average Loss: 0.2401
# Validation Loss: 0.1225
# Validation Accuracy: 95.11
# Epoch 4/15
# Training Average Loss: 0.1815
# Validation Loss: 0.1695
# Validation Accuracy: 92.33
# Epoch 5/15
# Training Average Loss: 0.1756
# Validation Loss: 0.7289
# Validation Accuracy: 74.78
# Epoch 6/15
# Training Average Loss: 0.1758
# Validation Loss: 0.2924
# Validation Accuracy: 88.30
# Epoch 7/15
# Training Average Loss: 0.1313
# Validation Loss: 0.2524
# Validation Accuracy: 88.02
# Epoch 8/15
# Training Average Loss: 0.1209
# Validation Loss: 0.2007
# Validation Accuracy: 92.43
# Epoch 9/15
# Training Average Loss: 0.1290
# Validation Loss: 0.0987
# Validation Accuracy: 95.97
# Epoch 10/15
# Training Average Loss: 0.0886
# Validation Loss: 0.0476
# Validation Accuracy: 98.37
# Epoch 11/15
# Training Average Loss: 0.0828
# Validation Loss: 0.0688
# Validation Accuracy: 97.12
# Epoch 12/15
# Training Average Loss: 0.0782
# Validation Loss: 0.0688
# Validation Accuracy: 97.12
# Epoch 13/15
# Training Average Loss: 0.0739
# Validation Loss: 0.0394
# Validation Accuracy: 98.56
# Epoch 14/15
# Training Average Loss: 0.0454
# Validation Loss: 0.0419
# Validation Accuracy: 98.27
# Epoch 15/15
# Training Average Loss: 0.0386
# Validation Loss: 0.0412
# Validation Accuracy: 98.37
# Best Validation Accuracy in Fold 2: 98.56%
# -----------------------------------------------------------------
#
# --------------Fold 3------------
# Train size: 4173, Val size: 1043
# Epoch 1/15
# Training Average Loss: 0.1340
# Validation Loss: 8.6870
# Validation Accuracy: 35.19
# Epoch 2/15
# Training Average Loss: 0.1197
# Validation Loss: 30.1536
# Validation Accuracy: 25.79
# Epoch 3/15
# Training Average Loss: 0.1913
# Validation Loss: 1.7984
# Validation Accuracy: 41.90
# Epoch 4/15
# Training Average Loss: 0.1789
# Validation Loss: 0.1751
# Validation Accuracy: 91.66
# Epoch 5/15
# Training Average Loss: 0.1502
# Validation Loss: 0.2054
# Validation Accuracy: 92.23
# Epoch 6/15
# Training Average Loss: 0.1508
# Validation Loss: 0.7441
# Validation Accuracy: 79.10
# Epoch 7/15
# Training Average Loss: 0.1282
# Validation Loss: 0.1657
# Validation Accuracy: 93.96
# Epoch 8/15
# Training Average Loss: 0.1033
# Validation Loss: 0.1454
# Validation Accuracy: 94.44
# Epoch 9/15
# Training Average Loss: 0.1095
# Validation Loss: 0.3525
# Validation Accuracy: 87.54
# Epoch 10/15
# Training Average Loss: 0.1012
# Validation Loss: 0.5939
# Validation Accuracy: 76.99
# Epoch 11/15
# Training Average Loss: 0.0748
# Validation Loss: 0.1245
# Validation Accuracy: 96.45
# Epoch 12/15
# Training Average Loss: 0.0605
# Validation Loss: 0.0708
# Validation Accuracy: 97.51
# Epoch 13/15
# Training Average Loss: 0.0450
# Validation Loss: 0.1017
# Validation Accuracy: 97.22
# Epoch 14/15
# Training Average Loss: 0.0434
# Validation Loss: 0.0747
# Validation Accuracy: 97.22
# Epoch 15/15
# Training Average Loss: 0.0491
# Validation Loss: 0.0686
# Validation Accuracy: 97.60
# Best Validation Accuracy in Fold 3: 97.60%
# -----------------------------------------------------------------
#
# --------------Fold 4------------
# Train size: 4173, Val size: 1043
# Epoch 1/15
# Training Average Loss: 0.1360
# Validation Loss: 0.1820
# Validation Accuracy: 95.30
# Epoch 2/15
# Training Average Loss: 0.1112
# Validation Loss: 0.5184
# Validation Accuracy: 80.25
# Epoch 3/15
# Training Average Loss: 0.1603
# Validation Loss: 0.2450
# Validation Accuracy: 89.55
# Epoch 4/15
# Training Average Loss: 0.1779
# Validation Loss: 0.6022
# Validation Accuracy: 80.54
# Epoch 5/15
# Training Average Loss: 0.1812
# Validation Loss: 0.5242
# Validation Accuracy: 88.30
# Epoch 6/15
# Training Average Loss: 0.1592
# Validation Loss: 0.5911
# Validation Accuracy: 70.28
# Epoch 7/15
# Training Average Loss: 0.1141
# Validation Loss: 0.2571
# Validation Accuracy: 91.18
# Epoch 8/15
# Training Average Loss: 0.1086
# Validation Loss: 0.1329
# Validation Accuracy: 94.82
# Epoch 9/15
# Training Average Loss: 0.0976
# Validation Loss: 0.0965
# Validation Accuracy: 95.88
# Epoch 10/15
# Training Average Loss: 0.0952
# Validation Loss: 0.1389
# Validation Accuracy: 94.92
# Epoch 11/15
# Training Average Loss: 0.0958
# Validation Loss: 0.0630
# Validation Accuracy: 97.60
# Epoch 12/15
# Training Average Loss: 0.0687
# Validation Loss: 0.1627
# Validation Accuracy: 93.38
# Epoch 13/15
# Training Average Loss: 0.0645
# Validation Loss: 0.0490
# Validation Accuracy: 97.99
# Epoch 14/15
# Training Average Loss: 0.0452
# Validation Loss: 0.0397
# Validation Accuracy: 98.66
# Epoch 15/15
# Training Average Loss: 0.0432
# Validation Loss: 0.0383
# Validation Accuracy: 98.56
# Best Validation Accuracy in Fold 4: 98.66%
# -----------------------------------------------------------------
#
# --------------Fold 5------------
# Train size: 4173, Val size: 1043
# Epoch 1/15
# Training Average Loss: 0.1218
# Validation Loss: 1.3488
# Validation Accuracy: 74.50
# Epoch 2/15
# Training Average Loss: 0.1306
# Validation Loss: 1.7417
# Validation Accuracy: 64.14
# Epoch 3/15
# Training Average Loss: 0.1995
# Validation Loss: 0.5650
# Validation Accuracy: 72.48
# Epoch 4/15
# Training Average Loss: 0.2494
# Validation Loss: 42.4253
# Validation Accuracy: 25.70
# Epoch 5/15
# Training Average Loss: 0.2657
# Validation Loss: 0.2103
# Validation Accuracy: 91.56
# Epoch 6/15
# Training Average Loss: 0.1597
# Validation Loss: 0.1477
# Validation Accuracy: 93.48
# Epoch 7/15
# Training Average Loss: 0.1489
# Validation Loss: 0.8538
# Validation Accuracy: 72.39
# Epoch 8/15
# Training Average Loss: 0.1333
# Validation Loss: 0.2912
# Validation Accuracy: 88.02
# Epoch 9/15
# Training Average Loss: 0.1480
# Validation Loss: 0.0934
# Validation Accuracy: 96.84
# Epoch 10/15
# Training Average Loss: 0.1268
# Validation Loss: 0.1263
# Validation Accuracy: 93.48
# Epoch 11/15
# Training Average Loss: 0.1050
# Validation Loss: 0.0760
# Validation Accuracy: 96.74
# Epoch 12/15
# Training Average Loss: 0.0868
# Validation Loss: 0.0790
# Validation Accuracy: 97.03
# Epoch 13/15
# Training Average Loss: 0.0670
# Validation Loss: 0.0527
# Validation Accuracy: 97.60
# Epoch 14/15
# Training Average Loss: 0.0600
# Validation Loss: 0.0530
# Validation Accuracy: 97.51
# Epoch 15/15
# Training Average Loss: 0.0576
# Validation Loss: 0.0558
# Validation Accuracy: 97.32
# Best Validation Accuracy in Fold 5: 97.60%
# -----------------------------------------------------------------
#
#
# Test Loss: 0.8532
# Test Accuracy: 81.89
# tensor(81.8910, device='cuda:0')
